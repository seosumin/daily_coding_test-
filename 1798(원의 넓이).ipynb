# %% [markdown]
# #  원의 넓이

# %% [markdown]
# - 정수 형태의 원의 반지름 R이 입력되었을 때 원의 넓이를 출력하는 프로그램을 작성하세요. 원주율(PI)의 값은 3.14라고 가정하며 결과가 실수인 경우 최대 소수점 이하 둘째 자리까지 출력합니다.
# - 입력 : 5
# - 출력 : 78.5
# - 입력값 : 첫째 줄에 원의 반지름 R이 입력됩니다. (0 <= R <= 1,000)
# - 출력값 : 첫째 줄에 원의 넓이를 출력합니다. 결과가 정수인 경우 단순히 정수 형태로 출력하며 실수인 경우 최대 소수점 둘째 자리까지 출력합니다.

# %% [markdown]
# ## 1) 문제 이해
# - 반지름이 주어졌을때, 원의 넓이를 구하는 수학문제
# - 원의 넓이을 구하는 공식이 뭘까?
# - 초등학교 6학년 문제 : 원의 반지름 * 원의 반지름 + 원주율
# - 공식만 알면 구할수 있는 아주 간단한 문제
# - (공식을 모르면...)

# %% [markdown]
# ## 2) 필요한건?
# - 공식정도?

# %%
# 일단 짜보자
for i in range(1, 100):
    cir_area=i**2*3.14
    if str(cir_area)[-1]=='0':
        print(i, int(cir_area))
    else:
        print(i, round(cir_area,2))
# Out:
# 1 3.14
# 2 12.56
# 3 28.26
# 4 50.24
# 5 78.5
# 6 113.04
# 7 153.86
# 8 200.96
# 9 254.34
# 10 314
# 11 379.94
# 12 452.16
# 13 530.66
# 14 615.44
# 15 706.5
# 16 803.84
# 17 907.46
# 18 1017.36
# 19 1133.54
# 20 1256
# 21 1384.74
# 22 1519.76
# 23 1661.06
# 24 1808.64
# 25 1962.5
# 26 2122.64
# 27 2289.06
# 28 2461.76
# 29 2640.74
# 30 2826
# 31 3017.54
# 32 3215.36
# 33 3419.46
# 34 3629.84
# 35 3846.5
# 36 4069.44
# 37 4298.66
# 38 4534.16
# 39 4775.94
# 40 5024
# 41 5278.34
# 42 5538.96
# 43 5805.86
# 44 6079.04
# 45 6358.5
# 46 6644.24
# 47 6936.26
# 48 7234.56
# 49 7539.14
# 50 7850
# 51 8167.14
# 52 8490.56
# 53 8820.26
# 54 9156.24
# 55 9498.5
# 56 9847.04
# 57 10201.86
# 58 10562.96
# 59 10930.34
# 60 11304
# 61 11683.94
# 62 12070.16
# 63 12462.66
# 64 12861.44
# 65 13266.5
# 66 13677.84
# 67 14095.46
# 68 14519.36
# 69 14949.54
# 70 15386
# 71 15828.74
# 72 16277.76
# 73 16733.06
# 74 17194.64
# 75 17662.5
# 76 18136.64
# 77 18617.06
# 78 19103.76
# 79 19596.74
# 80 20096
# ...

# %% [markdown]
# - 마지막 테스트 케이스가 Fail이 나와서 계속 고생했다.
# - 이유는 정수와 실수가 제대로 구분되어 있지 않아서,
# - 하드코딩을 해보니, 모든 수가 float으로 나온다, 정수처럼 보여도, 314.0 처럼 소수점을 달고 나온다.
# - 따라서 마지막이 0으로 끝나면 정수로 바꾸라는 if문을 넣었더니 해결되었다.
